# %%
import urllib.request

a = urllib.request.urlopen('http://openapi.seoul.go.kr:8088/6b46504b456b6f6f313130734d624851/xml/SearchParkingInfo/1/5/')
for i in a:
    print(i.decode('UTF-8'))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
#
# <SearchParkingInfo>
#
# <list_total_count>9803</list_total_count>
#
# <RESULT>
#
# <CODE>INFO-230</CODE>
#
# <MESSAGE>해당 서비스(OpenAPI)는 공개전 서비스(OpenAPI)로 사용이 가능합니다.</MESSAGE>
#
# </RESULT>
#
# <row>
#
# <PARKING_CODE>1542514</PARKING_CODE>
#
# <PARKING_NAME>신정1,3동 복개(구)</PARKING_NAME>
#
# <ADDR>양천구 신정동 1031-0</ADDR>
#
# <PARKING_TYPE_NM>노상 주차장</PARKING_TYPE_NM>
#
# <OPERATION_RULE_NM>시간제 주차장</OPERATION_RULE_NM>
#
# <TEL>02-2645-1158</TEL>
#
# <CAPACITY>139</CAPACITY>
#
# <PAY_NM>유료</PAY_NM>
#
# <NIGHT_FREE_OPEN_NM>야간 미개방</NIGHT_FREE_OPEN_NM>
#
# <WEEKDAY_BEGIN_TIME>0900</WEEKDAY_BEGIN_TIME>
#
# <WEEKDAY_END_TIME>1900</WEEKDAY_END_TIME>
#
# <WEEKEND_BEGIN_TIME>0900</WEEKEND_BEGIN_TIME>
#
# <WEEKEND_END_TIME>1300</WEEKEND_END_TIME>
#
# <HOLIDAY_BEGIN_TIME>0000</HOLIDAY_BEGIN_TIME>
#
# <HOLIDAY_END_TIME>0000</HOLIDAY_END_TIME>
#
# <WORK_DTTM>2017-09-22 17:24:16.0</WORK_DTTM>
#
# <SATURDAY_PAY_NM>무료</SATURDAY_PAY_NM>
#
# ...

# %%
a.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-395a8f131acc> in <module>()
# ----> 1 a.read()
#
# AttributeError: 'Request' object has no attribute 'read'
