# %%
from bs4 import BeautifulSoup as BS
import json

snack_txt = open('D:/seoul.txt','r', encoding='utf-8')

snack_list = []

for i in snack_txt:
    try:
        snack_list.append(json.loads(i))
    except:
        continue
snack_txt.close()

len(snack_list)
# Out:
# 209997

# %%
snack_list[:10]
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Aug 29 23:52:53 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 3251218345,
#      'id_str': '3251218345',
#      'indices': [3, 12],
#      'name': 'J-Hope México😇',
#      'screen_name': 'JHopeMex'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 902680486962749444,
#   'id_str': '902680486962749444',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Aug 29 20:40:32 +0000 2017',
# ...
