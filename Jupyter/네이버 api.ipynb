# %%
import os
import sys
import urllib.request
import re

# %%
client_id = "pNeL9M2Busi7vWn4XkW6"
client_secret = "nTY9Mj5v2K"
encText = urllib.parse.quote("과자는 역시")
start_num = [1,101,201,301,401,501,601,701,801,901]
url = "https://openapi.naver.com/v1/search/blog?query=" + encText + '&display=100&start='# json 결과
text_outcome = []
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

for i in start_num:
    url_gen = url+str(i)
    request = urllib.request.Request(url_gen)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    
    if(rescode==200):
        response_body = response.readlines()
        for i in response_body:
            if 'description' in i.decode('utf-8'):
                text_outcome.append(re.sub('<[a-z/<>]*>','',i.decode('utf-8').replace(',\n','')))
            elif 'postdate' in i.decode('utf-8'):
                text_outcome.append(i.decode('utf-8').replace('\n','') )
    else:
        print("Error Code:" + rescode)

# %%
len(text_outcome)
# Out:
# 2000

# %%
if(rescode==200):
    response_body = response.readlines()
    for i in response_body:
        if 'description' in i.decode('utf-8'):
            text_outcome.append(re.sub('<[a-z/<>]*>','',i.decode('utf-8').replace(',\n','')))
        elif 'postdate' in i.decode('utf-8'):
            text_outcome.append(i.decode('utf-8').replace('\n','') )
else:
    print("Error Code:" + rescode)

# %%
text_outcome
# Out:
# ['"description": "쌀과자하면 예전 제사 때 썼던 한과가 제일 먼저 생각나네요.. 물론 한과도 물론 좋은 쌀과자이지만 대중적인 쌀과자는 일명 뻥튀기라 해서 둥그런 모양을 지닌.. 아시지요.. 이젠 쌀과자에 현미,렌틸콩... "',
#  '"postdate": "20170823"',
#  '"description": "배가 고파서 과자를 먹었지요 ~ 과자가 갑자기 생각나서 봤는데 마침 있더라구요 좋아하는 감자과자 ! ㅋㅋㅋㅋ 그것도 고추장맛 스낵 ㅋㅋㅋㅋ 맵지도 않고 그냥 달달하면서 맛있어요 ! 그런데 제가 먹을려고... "',
#  '"postdate": "20170920"',
#  '"description": "이래서 다들 답례품이나 선물용으로 코코호도를 찾나 봐요~ 코코호도에 호두과자만 있느냐!!!! 아닙니다~~~ 선물용 견과류도 있는데요! 역시나 박스 포장으로 잘 되어있기에 선물하기에 좋아요~ 한봉 한봉 먹기... "',
#  '"postdate": "20170413"',
#  '"description": "계란과자는 역시 해태! 오리지날이지~ 추억의 과자, 계란과자!!! 회식으로 늦는 남편을 한없이 기다리며 아이와 놀다 간식으로 먹었답니다. 어릴적 자주 먹던 과자!! 좋아했던 과자~ 이제는 여러 브랜드에서... "',
#  '"postdate": "20170225"',
#  '"description": "호두과자는 역시 코코호도 가끔 사먹게되는 호두과자 예전에는 고속도로 휴게소에 갈때면 꼭 먹었던 간식이죠 하지만 휴게소 호두과자가 예전처럼 맛이 있지는 않다는~~ 코코호도에 가면 우선 맛보기로 하나... "',
#  '"postdate": "20161118"',
#  '"description": "선물용호두과자 간식용 호두과자 코코호도 역시 호두과자 하면 코코호도!ㅋㅋㅋ 언제 먹어도 맛있고 고소한게 늘 만족해서 제가 선물하기에도 좋고 받아도 기분좋은 고런 성의?인거같아요 ㅎㅎㅎ 답례품으로... "',
# ...

# %%
description = []
postdate = []
for i in text_outcome:
    if 'description' in i:
        description.append(re.sub('description: ','',i.replace('"','')))
    elif 'postdate' in i:
        postdate.append(re.sub('postdate: ','',i.replace('"','')))

# %%
len(description)
# Out:
# 1000

# %%
postdate
# Out:
# ['20170823',
#  '20170920',
#  '20170413',
#  '20170225',
#  '20161118',
#  '20170804',
#  '20170823',
#  '20170720',
#  '20160303',
#  '20170430',
#  '20170910',
#  '20170719',
#  '20170831',
#  '20170720',
#  '20160309',
#  '20161128',
#  '20170607',
#  '20170415',
#  '20150728',
#  '20170906',
#  '20160327',
#  '20150211',
#  '20170718',
#  '20170121',
#  '20150730',
#  '20170314',
#  '20170512',
#  '20160217',
#  '20130817',
#  '20170414',
#  '20151001',
#  '20170429',
#  '20150110',
#  '20170314',
#  '20160604',
#  '20150308',
#  '20170825',
#  '20141214',
#  '20161210',
#  '20170601',
#  '20140618',
#  '20160127',
#  '20170914',
#  '20141230',
#  '20130711',
#  '20140416',
#  '20160206',
#  '20140910',
#  '20150702',
#  '20170828',
#  '20170917',
#  '20151019',
#  '20160810',
#  '20161130',
#  '20170913',
#  '20170628',
#  '20150218',
#  '20170703',
#  '20170512',
#  '20150504',
#  '20160928',
#  '20170208',
#  '20150323',
#  '20110324',
#  '20160927',
#  '20170913',
# ...

# %%
with open('d:/github/r/visualization/snack_proj/naver_txt.txt', 'w', encoding = 'utf-8') as z:
    for i in description:
        z.write(i)
        z.write('\n')

# %%
with open('d:/github/r/visualization/snack_proj/naver_date.txt', 'w', encoding = 'utf-8') as z:
    for i in postdate:
        z.write(i)
        z.write('\n')
