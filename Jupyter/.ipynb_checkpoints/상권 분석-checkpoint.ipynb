# %%
import json

from urllib.request import urlopen

# %%
base_line = 'Shanghai'
base_add = 'https://maps.googleapis.com/maps/api/geocode/json?address='
key = '&key=AIzaSyBfe7fL6OhxY4rcZ9N0QJ2IwOQsQeJhXZg'
url = urlopen(base_add+base_line+key)
a = url.readlines()

# %%
b = []
c = []

for i in range(len(a)):
    if 'location' in str(a[i]):
        b.append(str(a[i+1]).split('"')[2].split(':')[1].split(',')[0])
        c.append(str(a[i+2]).split('"')[2].split(':')[1].split('\\')[0])

# %%
str(a[49]).split('"')[2].split(':')[1].split('\\')[0]
# Out:
# ' -80.13541149999999'

# %%
search_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location='
search_mid = '&radius=20000&name='
go_find = 'Mcdonalds'

url1 = search_url+b[0]+','+c[0]+search_mid+go_find+key
a1 = urlopen(url1.replace(' ', '')).readlines()

# %%
a1
# Out:
# [b'{\n',
#  b'   "html_attributions" : [ "Listings by \\u003ca href=\\"http://www.openrice.com/\\"\\u003eOpenRice\\u003c/a\\u003e" ],\n',
#  b'   "next_page_token" : "CqQCGgEAAA2It9JDOuOhzUbSqEncKaNXa731c6Q1FLxpOm68QG0qPYHyfXRm7qpWfLVOIWQVKoKgeOCdkCK9qtr4FvIwUB6-h9CG3lBKAcTiv0UO4Vyx8NJka_B9zuoMjb-m5y9AQf6-DMzRCFcRLFjKjAhHfyk0mMtFB4nu5JX7wrIoz0ST0QLPmt9srW7D9Oih0XBFnVzmK_1yLcVoWqQqR249pDEwVGtSOkXOMYDBQ-oogKdPZsmVh3Wbs20B7vOgGy_bwRyrvZ3dUCRC0_btE5QR-e8fyH83yNneGVJ4DyrTj20jOHvLl_1-lfVDmu9a5IjPdr1eY1rzIc9P2Tf3K18qw-AOsEoPMJXEcJuUg-Gr7FvnD369Vjmg-kHarMqYR55C6hIQkH_7Q8dVKWdxPCxF07Hd8xoUZOGHkOhyO3xsny-p7RQXw4gdlG0",\n',
#  b'   "results" : [\n',
#  b'      {\n',
#  b'         "geometry" : {\n',
#  b'            "location" : {\n',
#  b'               "lat" : 31.4044722,\n',
#  b'               "lng" : 121.4820198\n',
#  b'            },\n',
#  b'            "viewport" : {\n',
#  b'               "northeast" : {\n',
#  b'                  "lat" : 31.4058626802915,\n',
# ...

# %%
MC_lat = []
MC_lng = []

for i in range(len(a1)):
    if 'location' in str(a1[i]):
        MC_lat.append(float(str(a1[i+1]).split('"')[2].split(':')[1].split(',')[0]))
        MC_lng.append(float(str(a1[i+2]).split('"')[2].split(':')[1].split('\\')[0]))

# %%
import gmplot

gmap = gmplot.GoogleMapPlotter(b[0], c[0], 13)

#gmap.heatmap(MC_lat, MC_lng)
#gmap.scatter(k,l, 'k', marker=True)
#gmap.plot(MC_lat, MC_lng, 'cornflowerblue', edge_width=10)
gmap.scatter(MC_lat, MC_lng, '#3B0B39', size=1000, marker=False)

gmap.draw("mymap.html")
