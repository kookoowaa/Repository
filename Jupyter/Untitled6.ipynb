# %%
import json

# %%
tweet_data = open('d:/incheon.txt')

# %%
tweet = []

for i in tweet_data:
    try:
        content = json.loads(i)
        tweet.append(content)
    except:
        continue

# %%
tweet[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Aug 31 03:28:31 +0000 2017',
#  'entities': {'hashtags': [{'indices': [24, 28], 'text': 'EXO'}],
#   'media': [{'display_url': 'pic.twitter.com/bnNc7rhIif',
#     'expanded_url': 'https://twitter.com/EXO_FANBASE/status/903090262829707264/photo/1',
#     'id': 903090223877197824,
#     'id_str': '903090223877197824',
#     'indices': [78, 101],
#     'media_url': 'http://pbs.twimg.com/media/DIhrxhpUEAACTCk.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DIhrxhpUEAACTCk.jpg',
#     'sizes': {'large': {'h': 635, 'resize': 'fit', 'w': 450},
#      'medium': {'h': 635, 'resize': 'fit', 'w': 450},
#      'small': {'h': 635, 'resize': 'fit', 'w': 450},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'source_status_id': 903090262829707264,
#     'source_status_id_str': '903090262829707264',
#     'source_user_id': 527508915,
#     'source_user_id_str': '527508915',
#     'type': 'photo',
# ...
