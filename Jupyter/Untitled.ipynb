# %%
client_id = 'pNeL9M2Busi7vWn4XkW6'
client_secret = 'nTY9Mj5v2K'

# %%
import os
import sys
import urllib.request

encText = urllib.parse.quote('동부간선도로')
#url = "https://openapi.naver.com/v1/map/geocode?query=" + encText # json 결과
url = "https://openapi.naver.com/v1/map/geocode.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-32-5d7b6e73f704> in <module>()
#       9 request.add_header("X-Naver-Client-Id",client_id)
#      10 request.add_header("X-Naver-Client-Secret",client_secret)
# ---> 11 response = urllib.request.urlopen(request)
#      12 rescode = response.getcode()
#      13 if(rescode==200):
#
# D:\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# D:\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
# ...

# %%
from pandas import DataFrame, Series
import pandas as pd
import numpy as np

# %%
road_names = pd.read_csv('./BA/data_set.csv')['road_name']
road_names
# Out:
# 0        성산로
# 1        사직로
# 2       자하문로
# 3        율곡로
# 4       창경궁로
# 5         종로
# 6        퇴계로
# 7        동호로
# 8       장충단로
# 9       세종대로
# 10       을지로
# 11       소파로
# 12       진흥로
# 13     평창문화로
# 14       망우로
# 15      경춘북로
# 16      천호대로
# 17       화랑로
# 18      동소문로
# 19       도봉로
# 20       동일로
# 21     분당수서로
# 22       통일로
# 23       오리로
# 24       연희로
# 25       금하로
# 26     남부순환로
# 27       화곡로
# 28       경인로
# 29      김포대로
# 30       강서로
# 31      영등포로
# 32      서빙고로
# 33       뚝섬로
# 34    동부간선도로
# 35     여의대방로
# 36       문성로
# 37      강남대로
# 38      사평대로
# 39      반포대로
# 40       언주로
# 41      밤고개로
# 42      테헤란로
# 43     백제고분로
# Name: road_name, dtype: object

# %%
roads = []

# %%
for i in road_names[35:]:
    encText = urllib.parse.quote(i)
    #url = "https://openapi.naver.com/v1/map/geocode?query=" + encText # json 결과
    url = "https://openapi.naver.com/v1/map/geocode.xml?query=" + encText # xml 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        roads.append(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)

# %%
roads[0].find('<y>')
# Out:
# 618

# %%
roads_x = []
roads_y = []
for i in range(len(roads)):
    roads_x.append(float(roads[i][roads[i].find('<x>')+3:roads[i].find('<x>')+11]))
    roads_y.append(float(roads[i][roads[i].find('<y>')+3:roads[i].find('<y>')+10]))
roads_x = roads_x[:34] + [127.0712] +roads_x[34:]
roads_y = roads_y[:34] + [37.6042] + roads_y[34:]

# %%
road = DataFrame(road_names)
road['x'] = roads_x
road['y'] = roads_y
road
# Out:
#    road_name         x        y
# 0        성산로  126.9448  37.5642
# 1        사직로  126.9707  37.5757
# 2       자하문로  126.9674  37.5892
# 3        율곡로  126.9962  37.5762
# 4       창경궁로  126.9982  37.5655
# 5         종로  127.0006  37.5709
# 6        퇴계로  126.9978  37.5615
# 7        동호로  127.0014  37.5703
# 8       장충단로  127.0058  37.5599
# 9       세종대로  126.9753  37.5628
# 10       을지로  126.9947  37.5664
# 11       소파로  126.9850  37.5569
# 12       진흥로  126.9566  37.6077
# 13     평창문화로  126.9728  37.6073
# 14       망우로  127.0623  37.5893
# 15      경춘북로  127.1035  37.6183
# 16      천호대로  127.0488  37.5697
# 17       화랑로  127.0519  37.6086
# 18      동소문로  127.0211  37.5983
# 19       도봉로  127.0302  37.6107
# 20       동일로  127.0663  37.5464
# 21     분당수서로  127.0759  37.5009
# 22       통일로  126.9700  37.5614
# 23       오리로  126.8785  37.4441
# 24       연희로  126.9348  37.5743
# 25       금하로  126.9068  37.4523
# 26     남부순환로  126.9758  37.4764
# 27       화곡로  126.8624  37.5712
# ...

# %%
road.to_csv('./road_coord.csv')
